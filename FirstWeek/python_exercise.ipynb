# %% [markdown]
# The following list contains information about some international Cities. The first entry gives the name, the second the population and the third the continent. (Since the list was generated by ChatGPT, the values might be a bit off.)

# %%
cities = [["Tokyo", 37435191, "Asia"], ["Delhi", 29399141, "Asia"], ["Shanghai", 26317104, "Asia"], ["São Paulo", 21846507, "South America"], 
    ["Mexico City", 21671908, "North America"], ["Cairo", 21169189, "Africa"], ["Dhaka", 21114343, "Asia"], ["Mumbai", 20667656, "Asia"], 
    ["Beijing", 20035455, "Asia"], ["Osaka", 19222665, "Asia"], ["Karachi", 16459424, "Asia"], ["Chongqing", 16382376, "Asia"], ["Istanbul", 15462452, "Europe/Asia"], 
    ["Buenos Aires", 15159552, "South America"], ["Kolkata", 14910352, "Asia"], ["Lagos", 14862000, "Africa"], ["Kinshasa", 14557438, "Africa"], 
    ["Manila", 14000000, "Asia"], ["Rio de Janeiro", 13458000, "South America"], ["Tianjin", 13245000, "Asia"], ["Guangzhou", 13080500, "Asia"], 
    ["Los Angeles", 12815475, "North America"], ["Moscow", 12615279, "Europe"], ["Shenzhen", 12528300, "Asia"], ["Jakarta", 10770487, "Asia"], 
    ["London", 9304016, "Europe"], ["Paris", 11017000, "Europe"], ["Madrid", 6845117, "Europe"], ["Rome", 2873000, "Europe"], ["Berlin", 3644826, "Europe"], 
    ["Athens", 3153324, "Europe"], ["Vienna", 1900000, "Europe"]]

# %% [markdown]
# 1. How many cities are there?

# %%
number_of_cities = len(cities)
number_of_cities
# Out:
# 32

# %% [markdown]
# 2. What is the population of the seventh city?

# %%
cities[6][1]
# Out:
# 21114343

# %% [markdown]
# 3. What is the continent of the second to last city?

# %%
print(cities[-2][-1])
# Out:
# Europe

# %% [markdown]
# 4. What is the sum of the population?

# %%
mean = 0
for i in range(len(cities)):
    mean += cities[i][1]
mean
# Out:
# 487923077

# %% [markdown]
# 5. What is the average population of the above cities?

# %%
mean/len(cities)
# Out:
# 15247596.15625

# %% [markdown]
# 6. What is the total population of all cities in Europe?

# %%
europe_list = []
for i in range(len(cities)):
    if cities[i][-1] == "Europe" and "Europe/Asia":
        europe_list.append(cities[i][-2])
europe_list
# alternatively list comprehension
europe_list_comp = [cities[x][-2] for x in range(len(cities)) if cities[x][-1] in ["Europe", "Europe/Asia"]]
sum(europe_list_comp)
# Out:
# 66815014
